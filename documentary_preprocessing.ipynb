# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('main_data1.csv' , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill SkarsgÃ¥rd     Nicholas Hoult
# 7504      James Mangold  TimothÃ©e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
documentary_df = df[df['genres'].str.contains('Documentary')]

# %%
documentary_df
# Out:
#        director_name                                  actor_1_name  \
# 4        Doug Walker                                   Doug Walker
# 462   Jacques Perrin                       Pedro ArmendÃÂ¡riz Jr.
# 697     Kenny Ortega                        Misha Gabriel Hamilton
# 1702  Jacques Perrin                                Jacques Perrin
# 2067   Jeff Tremaine                                   Bam Margera
# ...              ...                                           ...
# 6966         Yoshiki                                       Yoshiki
# 7067        BeyoncÃ©                                      BeyoncÃ©
# 7430    Fiona Robert                                  Fiona Robert
# 7459  Michael Felker                           Adam David Thompson
# 7463  Morgan Neville  Morgan Neville (director); Pharrell Williams
#
#          actor_2_name    actor_3_name                             genres  \
# 4          Rob Walker         unknown                        Documentary
# ...

# %%
documentary_df.reset_index(drop=True , inplace=True)

# %%
documentary_df
# Out:
#       director_name                                  actor_1_name  \
# 0       Doug Walker                                   Doug Walker
# 1    Jacques Perrin                       Pedro ArmendÃÂ¡riz Jr.
# 2      Kenny Ortega                        Misha Gabriel Hamilton
# 3    Jacques Perrin                                Jacques Perrin
# 4     Jeff Tremaine                                   Bam Margera
# ..              ...                                           ...
# 176         Yoshiki                                       Yoshiki
# 177        BeyoncÃ©                                      BeyoncÃ©
# 178    Fiona Robert                                  Fiona Robert
# 179  Michael Felker                           Adam David Thompson
# 180  Morgan Neville  Morgan Neville (director); Pharrell Williams
#
#         actor_2_name    actor_3_name                             genres  \
# 0         Rob Walker         unknown                        Documentary
# ...

# %%
documentary_df.to_csv('documentary.csv')
