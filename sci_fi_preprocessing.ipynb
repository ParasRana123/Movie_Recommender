# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
sci_fi_df = df[df['genres'].str.contains('Sci-Fi')]

# %%
sci_fi_df
# Out:
#        director_name      actor_1_name         actor_2_name  \
# 0      James Cameron       CCH Pounder     Joel David Moore
# 5     Andrew Stanton      Daryl Sabara      Samantha Morton
# 7        Joss Whedon   Chris Hemsworth    Robert Downey Jr.
# 9        Zack Snyder      Henry Cavill         Lauren Cohan
# 10      Bryan Singer      Kevin Spacey        Marlon Brando
# ...              ...               ...                  ...
# 5308       Joe Miale          Lee Pace   B̩r̩nice Marlohe
# 5311   Nikolaj Arcel        Idris Elba  Matthew McConaughey
# 5321      Clay Staub  Milo Ventimiglia        Bridget Regan
# 7103      Shawn Levy     Ryan Reynolds         Hugh Jackman
# 7104   S.J. Clarkson    Dakota Johnson       Sydney Sweeney
#
#             actor_3_name                                             genres  \
# 0              Wes Studi                    Action Adventure Fantasy Sci-Fi
# 5           Polly Walker                            Action Adventure Sci-Fi
# ...

# %%
sci_fi_df.reset_index(drop=True , inplace=True)

# %%
sci_fi_df
# Out:
#       director_name      actor_1_name         actor_2_name  \
# 0     James Cameron       CCH Pounder     Joel David Moore
# 1    Andrew Stanton      Daryl Sabara      Samantha Morton
# 2       Joss Whedon   Chris Hemsworth    Robert Downey Jr.
# 3       Zack Snyder      Henry Cavill         Lauren Cohan
# 4      Bryan Singer      Kevin Spacey        Marlon Brando
# ..              ...               ...                  ...
# 645       Joe Miale          Lee Pace   B̩r̩nice Marlohe
# 646   Nikolaj Arcel        Idris Elba  Matthew McConaughey
# 647      Clay Staub  Milo Ventimiglia        Bridget Regan
# 648      Shawn Levy     Ryan Reynolds         Hugh Jackman
# 649   S.J. Clarkson    Dakota Johnson       Sydney Sweeney
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action Adventure Fantasy Sci-Fi
# 1          Polly Walker                            Action Adventure Sci-Fi
# ...

# %%
sci_fi_df.to_csv('sci_fi.csv')
