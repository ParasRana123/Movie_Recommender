# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
history_df = df[df['genres'].str.contains('History')]

# %%
history_df
# Out:
#          director_name        actor_1_name         actor_2_name  \
# 20        Ridley Scott           Mark Addy         William Hurt
# 98         Michael Bay     Jennifer Garner           Jaime King
# 100       Oliver Stone     Anthony Hopkins  Angelina Jolie Pitt
# 143       Edward Zwick          Tom Cruise         Tony Goldwyn
# 156         Peter Weir        James D'Arcy          Lee Ingleby
# ...                ...                 ...                  ...
# 7390   Simon Verhoeven        Elan Ben Ali           Tijan Njie
# 7398  Chiwetel Ejiofor            Jay Will        Mary J. Blige
# 7419     Sean McNamara        Dennis Quaid  Penelope Ann Miller
# 7462     Jason Reitman     Gabriel LaBelle       Rachel Sennott
# 7504     James Mangold  Timoth̩e Chalamet        Edward Norton
#
#                 actor_3_name  \
# 20              Scott Grimes
# 98                      Mako
# 100            Brian Blessed
# 143            Chad Lindberg
# 156          David Threlfall
# ...

# %%
history_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
history_df.reset_index(drop=True , inplace=True)

# %%
history_df
# Out:
#         director_name        actor_1_name         actor_2_name  \
# 0        Ridley Scott           Mark Addy         William Hurt
# 1         Michael Bay     Jennifer Garner           Jaime King
# 2        Oliver Stone     Anthony Hopkins  Angelina Jolie Pitt
# 3        Edward Zwick          Tom Cruise         Tony Goldwyn
# 4          Peter Weir        James D'Arcy          Lee Ingleby
# ..                ...                 ...                  ...
# 301   Simon Verhoeven        Elan Ben Ali           Tijan Njie
# 302  Chiwetel Ejiofor            Jay Will        Mary J. Blige
# 303     Sean McNamara        Dennis Quaid  Penelope Ann Miller
# 304     Jason Reitman     Gabriel LaBelle       Rachel Sennott
# 305     James Mangold  Timoth̩e Chalamet        Edward Norton
#
#                actor_3_name  \
# 0              Scott Grimes
# 1                      Mako
# 2             Brian Blessed
# 3             Chad Lindberg
# 4           David Threlfall
# ..                      ...
# ...

# %%
history_df.to_csv('history.csv')
