# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('main_data1.csv' , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
adventure_df = df[df['genres'].str.contains('Adventure')]

# %%
adventure_df
# Out:
#           director_name          actor_1_name         actor_2_name  \
# 0         James Cameron           CCH Pounder     Joel David Moore
# 1        Gore Verbinski           Johnny Depp        Orlando Bloom
# 2            Sam Mendes       Christoph Waltz         Rory Kinnear
# 5        Andrew Stanton          Daryl Sabara      Samantha Morton
# 6          Nathan Greno          Brad Garrett         Donna Murphy
# ...                 ...                   ...                  ...
# 7486       Ridley Scott           Paul Mescal         Pedro Pascal
# 7489  David Derrick Jr.       Auli'i Cravalho       Dwayne Johnson
# 7493      Justin Kurzel              Jude Law       Nicholas Hoult
# 7496      J. C. Chandor  Aaron Taylor-Johnson        Ariana DeBose
# 7500      Barry Jenkins          Aaron Pierre  Kelvin Harrison Jr.
#
#           actor_3_name                                             genres  \
# 0            Wes Studi                    Action Adventure Fantasy Sci-Fi
# ...

# %%
adventure_df.reset_index(drop=True , inplace=True)

# %%
adventure_df
# Out:
#           director_name          actor_1_name         actor_2_name  \
# 0         James Cameron           CCH Pounder     Joel David Moore
# 1        Gore Verbinski           Johnny Depp        Orlando Bloom
# 2            Sam Mendes       Christoph Waltz         Rory Kinnear
# 3        Andrew Stanton          Daryl Sabara      Samantha Morton
# 4          Nathan Greno          Brad Garrett         Donna Murphy
# ...                 ...                   ...                  ...
# 1123       Ridley Scott           Paul Mescal         Pedro Pascal
# 1124  David Derrick Jr.       Auli'i Cravalho       Dwayne Johnson
# 1125      Justin Kurzel              Jude Law       Nicholas Hoult
# 1126      J. C. Chandor  Aaron Taylor-Johnson        Ariana DeBose
# 1127      Barry Jenkins          Aaron Pierre  Kelvin Harrison Jr.
#
#           actor_3_name                                             genres  \
# 0            Wes Studi                    Action Adventure Fantasy Sci-Fi
# ...

# %%
adventure_df.to_csv('adventure.csv')
