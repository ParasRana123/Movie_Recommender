# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
thriller_df = df[df['genres'].str.contains('Thriller')]

# %%
thriller_df.reset_index(drop=True , inplace=True)

# %%
thriller_df
# Out:
#                                           director_name         actor_1_name  \
# 0                                            Sam Mendes      Christoph Waltz
# 1                                     Christopher Nolan            Tom Hardy
# 2                                            Peter Berg          Liam Neeson
# 3                                       Colin Trevorrow  Bryce Dallas Howard
# 4                                          Brett Ratner         Hugh Jackman
# ...                                                 ...                  ...
# 1988                                      Steve McQueen        Saoirse Ronan
# 1989  Scott Beck and Bryan Woods (directors/screenpl...           Hugh Grant
# 1990                                       Vicky Jenson        Rachel Zegler
# 1991                                       Halina Reijn        Nicole Kidman
# 1992                                      Ben Smallbone       Neal McDonough
#
# ...

# %%
thriller_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
thriller_df.to_csv("thriller.csv")
