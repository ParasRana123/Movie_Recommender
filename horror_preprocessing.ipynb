# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill SkarsgÃ¥rd     Nicholas Hoult
# 7504      James Mangold  TimothÃ©e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
# Extracting the movies with the genre Horror from the dataframe
horror_df = df[df['genres'].str.contains('Horror')]

# %%
horror_df
# Out:
#          director_name     actor_1_name           actor_2_name  \
# 39        Marc Forster    Peter Capaldi              Brad Pitt
# 63           Rob Cohen           Jet Li         Brendan Fraser
# 104   Francis Lawrence       Will Smith            Alice Braga
# 121         Tim Burton      Johnny Depp  ChloÃÂ« Grace Moretz
# 123       Joe Johnston  Anthony Hopkins         Simon Merrells
# ...                ...              ...                    ...
# 7491       Kyle Mooney   Jaeden Martell        Julian Dennison
# 7492   Uberto Pasolini    Ralph Fiennes       Juliette Binoche
# 7495  Steven C. Miller     Frank Grillo            Katrina Law
# 7502     Ben Smallbone   Neal McDonough          Dawn Olivieri
# 7503     Robert Eggers  Bill SkarsgÃ¥rd         Nicholas Hoult
#
#          actor_3_name                                    genres  \
# 39      Mireille Enos   Action Adventure Horror Sci-Fi Thriller
# 63       Russell Wong  Action Adventure Fantasy Horror Thriller
# ...

# %%
horror_df.reset_index(drop=True , inplace=True)

# %%
horror_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
horror_df
# Out:
#         director_name     actor_1_name           actor_2_name  \
# 0        Marc Forster    Peter Capaldi              Brad Pitt
# 1           Rob Cohen           Jet Li         Brendan Fraser
# 2    Francis Lawrence       Will Smith            Alice Braga
# 3          Tim Burton      Johnny Depp  ChloÃÂ« Grace Moretz
# 4        Joe Johnston  Anthony Hopkins         Simon Merrells
# ..                ...              ...                    ...
# 928       Kyle Mooney   Jaeden Martell        Julian Dennison
# 929   Uberto Pasolini    Ralph Fiennes       Juliette Binoche
# 930  Steven C. Miller     Frank Grillo            Katrina Law
# 931     Ben Smallbone   Neal McDonough          Dawn Olivieri
# 932     Robert Eggers  Bill SkarsgÃ¥rd         Nicholas Hoult
#
#         actor_3_name                                    genres  \
# 0      Mireille Enos   Action Adventure Horror Sci-Fi Thriller
# 1       Russell Wong  Action Adventure Fantasy Horror Thriller
# ...

# %%
horror_df.to_csv('horror.csv')
