# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('main_data1.csv' , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
romance_df = df[df['genres'].str.contains('Romance')]

# %%
romance_df
# Out:
#          director_name         actor_1_name          actor_2_name  \
# 6         Nathan Greno         Brad Garrett          Donna Murphy
# 23       James Cameron    Leonardo DiCaprio          Kate Winslet
# 27           Sam Raimi         J.K. Simmons          James Franco
# 43         Mike Newell      Jake Gyllenhaal         Richard Coyle
# 72    Robert Stromberg  Angelina Jolie Pitt        Sharlto Copley
# ...                ...                  ...                   ...
# 7450      Nate Edwards        Arsema Thomas  Darrell Britt-Gibson
# 7470        Sean Baker        Mikey Madison      Mark Eydelshteyn
# 7474    Caroline Lindy      Melissa Barrera           Tommy Dewey
# 7487        Jon M. Chu        Cynthia Erivo         Ariana Grande
# 7488      Vicky Jenson        Rachel Zegler          John Lithgow
#
#         actor_3_name                                             genres  \
# 6        M.C. Gainey  Adventure Animation Comedy Family Fantasy Musi...
# ...

# %%
romance_df.reset_index(drop=True , inplace=True)

# %%
romance_df
# Out:
#          director_name         actor_1_name          actor_2_name  \
# 0         Nathan Greno         Brad Garrett          Donna Murphy
# 1        James Cameron    Leonardo DiCaprio          Kate Winslet
# 2            Sam Raimi         J.K. Simmons          James Franco
# 3          Mike Newell      Jake Gyllenhaal         Richard Coyle
# 4     Robert Stromberg  Angelina Jolie Pitt        Sharlto Copley
# ...                ...                  ...                   ...
# 1362      Nate Edwards        Arsema Thomas  Darrell Britt-Gibson
# 1363        Sean Baker        Mikey Madison      Mark Eydelshteyn
# 1364    Caroline Lindy      Melissa Barrera           Tommy Dewey
# 1365        Jon M. Chu        Cynthia Erivo         Ariana Grande
# 1366      Vicky Jenson        Rachel Zegler          John Lithgow
#
#         actor_3_name                                             genres  \
# 0        M.C. Gainey  Adventure Animation Comedy Family Fantasy Musi...
# ...

# %%
romance_df.to_csv("romance.csv")
