# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill SkarsgÃ¥rd     Nicholas Hoult
# 7504      James Mangold  TimothÃ©e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
mystery_df = df[df['genres'].str.contains('Mystery')]

# %%
mystery_df
# Out:
#                                           director_name  \
# 8                                           David Yates
# 61                                      Martin Scorsese
# 77                                            Brad Bird
# 101                                         David Yates
# 102                                         Mike Newell
# ...                                                 ...
# 7426  The Eggers Brothers (directors/screenplay); Br...
# 7458                                       David Henrie
# 7468                                        Parker Finn
# 7476                                      Edward Berger
# 7488                                       Vicky Jenson
#
#                actor_1_name      actor_2_name     actor_3_name  \
# 8              Alan Rickman  Daniel Radcliffe     Rupert Grint
# 61    ChloÃÂ« Grace Moretz   Christopher Lee     Ray Winstone
# 77               Judy Greer       Chris Bauer  Thomas Robinson
# ...

# %%
mystery_df.reset_index(drop=True , inplace=True)

# %%
mystery_df.to_csv('mystery.csv')
