# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("main_data1.csv" , encoding='latin1')

# %%
df
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 0         James Cameron         CCH Pounder   Joel David Moore
# 1        Gore Verbinski         Johnny Depp      Orlando Bloom
# 2            Sam Mendes     Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan           Tom Hardy     Christian Bale
# 4           Doug Walker         Doug Walker         Rob Walker
# ...                 ...                 ...                ...
# 7501       Halina Reijn       Nicole Kidman   Harris Dickinson
# 7502      Ben Smallbone      Neal McDonough      Dawn Olivieri
# 7503      Robert Eggers     Bill Skarsg̴rd     Nicholas Hoult
# 7504      James Mangold  Timoth̩e Chalamet      Edward Norton
# 7505    Rachel Morrison        Ryan Destiny  Brian Tyree Henry
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
fantasy_df = df[df['genres'].str.contains('Fantasy')]

# %%
fantasy_df
# Out:
#         director_name     actor_1_name      actor_2_name  \
# 0       James Cameron      CCH Pounder  Joel David Moore
# 1      Gore Verbinski      Johnny Depp     Orlando Bloom
# 6        Nathan Greno     Brad Garrett      Donna Murphy
# 8         David Yates     Alan Rickman  Daniel Radcliffe
# 12     Gore Verbinski      Johnny Depp     Orlando Bloom
# ...               ...              ...               ...
# 7487       Jon M. Chu    Cynthia Erivo     Ariana Grande
# 7490  Marielle Heller        Amy Adams     Scoot McNairy
# 7494       Simon Otto        Brian Cox        Fiona Shaw
# 7497   Kenji Kamiyama        Brian Cox         Gaia Wise
# 7503    Robert Eggers  Bill Skarsg̴rd    Nicholas Hoult
#
#                  actor_3_name  \
# 0                   Wes Studi
# 1              Jack Davenport
# 6                 M.C. Gainey
# 8                Rupert Grint
# 12             Jack Davenport
# ...                       ...
# 7487            Michelle Yeoh
# ...

# %%
fantasy_df.reset_index(drop=True , inplace=True)

# %%
fantasy_df
# Out:
#        director_name     actor_1_name      actor_2_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom
# 2       Nathan Greno     Brad Garrett      Donna Murphy
# 3        David Yates     Alan Rickman  Daniel Radcliffe
# 4     Gore Verbinski      Johnny Depp     Orlando Bloom
# ..               ...              ...               ...
# 776       Jon M. Chu    Cynthia Erivo     Ariana Grande
# 777  Marielle Heller        Amy Adams     Scoot McNairy
# 778       Simon Otto        Brian Cox        Fiona Shaw
# 779   Kenji Kamiyama        Brian Cox         Gaia Wise
# 780    Robert Eggers  Bill Skarsg̴rd    Nicholas Hoult
#
#                 actor_3_name  \
# 0                  Wes Studi
# 1             Jack Davenport
# 2                M.C. Gainey
# 3               Rupert Grint
# 4             Jack Davenport
# ..                       ...
# 776            Michelle Yeoh
# 777  Arleigh Patrick Snowden
# ...

# %%
fantasy_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
fantasy_df.to_csv('fantasy.csv')
